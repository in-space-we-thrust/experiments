# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
exp_df = pd.read_csv('./csv/sensor_data_20250706_122455.csv', sep=',')

# %%
exp_df
# Out:
#                     Timestamp  Relative_Time  LVT-F_raw (psi)  \
# 0     2025-07-06 12:24:55.304       2445.755         3.056125
# 1     2025-07-06 12:24:55.367       2445.817         3.056125
# 2     2025-07-06 12:24:55.367       2445.817         3.056125
# 3     2025-07-06 12:24:55.367       2445.817         3.056125
# 4     2025-07-06 12:24:55.367       2445.817         3.056125
# ...                       ...            ...              ...
# 4814  2025-07-06 12:25:22.553       2473.004         2.196000
# 4815  2025-07-06 12:25:22.596       2473.046         2.196000
# 4816  2025-07-06 12:25:22.599       2473.050         2.196000
# 4817  2025-07-06 12:25:22.599       2473.050         2.196000
# 4818  2025-07-06 12:25:22.600       2473.051         2.196000
#
#       LVT-F_processed (psi)  LVT-L_raw (psi)  LVT-L_processed (psi)  \
# 0                      1.00         1.389375                    1.0
# 1                      1.00         1.389375                    1.0
# ...

# %%
exp_df.columns
# Out:
# Index(['Timestamp', 'Relative_Time', 'LVT-F_raw (psi)',
#        'LVT-F_processed (psi)', 'LVT-L_raw (psi)', 'LVT-L_processed (psi)',
#        'PT_M02_raw (psi)', 'PT_M02_processed (psi)', 'PT_F01_raw (psi)',
#        'PT_F01_processed (psi)', 'PT_F03_raw (psi)', 'PT_F03_processed (psi)',
#        'PT_F02_raw (°C)', 'PT_F02_processed (°C)', 'PT_M01_raw (psi)',
#        'PT_M01_processed (psi)', 'PT_L01_raw (°C)', 'PT_L01_processed (°C)',
#        'PT_L03_raw (°C)', 'PT_L03_processed (°C)', 'A_0_raw (°C)',
#        'A_0_processed (°C)', 'A_1_raw (°C)', 'A_1_processed (°C)',
#        'A_2_raw (°C)', 'A_2_processed (°C)', 'A_3_raw (°C)',
#        'A_3_processed (°C)', 'TYAGA_raw (kg)', 'TYAGA_processed (kg)',
#        'TYAGA2_raw (kg)', 'TYAGA2_processed (kg)', 'HPL1_raw (kg)',
#        'HPL1_processed (kg)', 'HPL2_raw (kg)', 'HPL2_processed (kg)',
#        'HPL3_raw (kg)', 'HPL3_processed (kg)', 'HPL4_raw (kg)',
# ...

# %%
exp_df['FT_F01_processed (rpm)'].plot()
# Out:
# <Axes: >

# %%
exp_df['FT_L01_processed (t)'].plot()
# Out:
# <Axes: >
