# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline

# %%
exp9_measure_2_df = pd.read_csv('./csv/exp9_measure_02.csv', sep=',')

# %%
exp9_measure_2_df
# Out:
#                      Timestamp  Relative_Time  PT-L01_2_1_V  PT-M02_2_2_V  \
# 0      2025-06-30 08:35:08.455       1779.589      0.875375      2.333875
# 1      2025-06-30 08:35:08.455       1779.589      0.875375      2.333875
# 2      2025-06-30 08:35:08.456       1779.590      0.875375      2.333875
# 3      2025-06-30 08:35:08.456       1779.590      0.875375      2.332875
# 4      2025-06-30 08:35:08.456       1779.590      0.875375      2.332875
# ...                        ...            ...           ...           ...
# 31478  2025-06-30 08:38:25.037       1976.171      0.871250      2.331500
# 31479  2025-06-30 08:38:25.037       1976.171      0.871250      2.331500
# 31480  2025-06-30 08:38:25.083       1976.216      0.871250      2.331500
# 31481  2025-06-30 08:38:25.083       1976.216      0.871250      2.331500
# 31482  2025-06-30 08:38:25.083       1976.216      0.871250      2.331500
#
#        PT-M01_2_3_V  reference_M_Pa
# 0            0.8565             0.0
# 1            0.8565             0.0
# 2            0.8565             0.0
# 3            0.8565             0.0
# 4            0.8565             0.0
# ...             ...             ...
# 31478        0.8465             0.0
# 31479        0.8465             0.0
# 31480        0.8465             0.0
# 31481        0.8465             0.0
# 31482        0.8465             0.0
#
# [31483 rows x 6 columns]

# %%
exp9_measure_2_df = exp9_measure_2_df.dropna()

# %%
# Построение графиков
plt.figure(figsize=(12, 8))
sns.scatterplot(data=exp9_measure_2_df, x='reference_M_Pa', y='PT-L01_2_1_V', label='PT-L01')
sns.scatterplot(data=exp9_measure_2_df, x='reference_M_Pa', y='PT-M02_2_2_V', label='PT-M02')
sns.scatterplot(data=exp9_measure_2_df, x='reference_M_Pa', y='PT-M01_2_3_V', label='PT-M01')
plt.xlabel('Давление на эталонном датчике, МПа')
plt.ylabel('Напряжение, В')
plt.title('Напряжение vs Давление на эталонном датчике')
plt.legend()
plt.savefig(f'./results/fig/exp_data.png')
plt.show()

# %%
# Создание графика
fig, ax1 = plt.subplots(figsize=(12, 6))

# Первая шкала Y для тарируемых датчиков
ax1.set_xlabel('Относительное время (с)')
ax1.set_ylabel('Напряжение (В)', color='tab:blue')
ax1.plot(exp9_measure_2_df['Relative_Time'], exp9_measure_2_df['PT-L01_2_1_V'], label='PT-L01_2_1_V', color='tab:blue', alpha=0.7)
ax1.plot(exp9_measure_2_df['Relative_Time'], exp9_measure_2_df['PT-M02_2_2_V'], label='PT-M02_2_2_V', color='tab:orange', alpha=0.7)
ax1.plot(exp9_measure_2_df['Relative_Time'], exp9_measure_2_df['PT-M01_2_3_V'], label='PT-M01_2_3_V', color='tab:green', alpha=0.7)
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.legend(loc='upper left')

# Вторая шкала Y для эталонного датчика давления
ax2 = ax1.twinx()
ax2.set_ylabel('Давление (МПа)', color='tab:red')
ax2.plot(exp9_measure_2_df['Relative_Time'], exp9_measure_2_df['reference_M_Pa'], label='Эталонное давление', color='tab:red', alpha=0.7)
ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.legend(loc='upper right')

# Настройка графика
plt.title('Изменение напряжения тарируемых датчиков и давления эталонного датчика во времени')
plt.grid()
plt.tight_layout()
plt.savefig(f'./results/fig/exp_data_time.png')
# Показ графика
plt.show()

# %%
# Находим моменты времени, когда значение эталонного датчика изменяется
reference_changes = exp9_measure_2_df['reference_M_Pa'].diff().abs() > 0

# %%
# Извлекаем времена обновления данных эталонного датчика
update_times = exp9_measure_2_df.loc[reference_changes, 'Relative_Time']

# %%
# Вычисляем разницу времени между обновлениями
update_intervals = update_times.diff().dropna()

# %%
# Находим минимальный интервал времени между обновлениями
min_update_interval = update_intervals.min()

# %%
print(f"Минимальный интервал времени между обновлениями данных эталонного датчика: {min_update_interval:.5f} секунд")
# Out:
# Минимальный интервал времени между обновлениями данных эталонного датчика: 0.88100 секунд

# %%
# Выбор данных с шагом, близким к минимальному интервалу обновления
selected_data = exp9_measure_2_df.iloc[::int(min_update_interval / (exp9_measure_2_df['Relative_Time'].diff().mean()))]

# %%
# Создание графика
fig, ax1 = plt.subplots(figsize=(12, 6))

# Первая шкала Y для тарируемых датчиков
ax1.set_xlabel('Относительное время (с)')
ax1.set_ylabel('Напряжение (В)', color='tab:blue')
ax1.plot(selected_data['Relative_Time'], selected_data['PT-L01_2_1_V'], label='PT-L01_2_1_V', color='tab:blue', alpha=0.7)
ax1.plot(selected_data['Relative_Time'], selected_data['PT-M02_2_2_V'], label='PT-M02_2_2_V', color='tab:orange', alpha=0.7)
ax1.plot(selected_data['Relative_Time'], selected_data['PT-M01_2_3_V'], label='PT-M01_2_3_V', color='tab:green', alpha=0.7)
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.legend(loc='upper left')

# Вторая шкала Y для эталонного датчика давления
ax2 = ax1.twinx()
ax2.set_ylabel('Давление (МПа)', color='tab:red')
ax2.plot(selected_data['Relative_Time'], selected_data['reference_M_Pa'], label='Эталонное давление', color='tab:red', alpha=0.7)
ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.legend(loc='upper right')

# Настройка графика
plt.title('Изменение напряжения тарируемых датчиков и давления эталонного датчика во времени \n(в одной дискретности с эталонным прибором)')
plt.grid()
plt.tight_layout()
plt.savefig(f'./results/fig/exp_data_time_high_sampling.png')
# Показ графика
plt.show()

# %%
selected_data.to_excel('./results/selected_data.xlsx')

# %%
selected_data
# Out:
#                      Timestamp  Relative_Time  PT-L01_2_1_V  PT-M02_2_2_V  \
# 0      2025-06-30 08:35:08.455       1779.589      0.875375      2.333875
# 141    2025-06-30 08:35:09.304       1780.438      0.871250      2.333875
# 282    2025-06-30 08:35:10.192       1781.325      0.869875      2.333750
# 423    2025-06-30 08:35:11.068       1782.201      0.871125      2.333000
# 564    2025-06-30 08:35:11.926       1783.060      0.870375      2.334500
# ...                        ...            ...           ...           ...
# 30879  2025-06-30 08:38:21.284       1972.417      0.868875      2.330125
# 31020  2025-06-30 08:38:22.198       1973.331      0.868375      2.330125
# 31161  2025-06-30 08:38:23.103       1974.236      0.870375      2.330875
# 31302  2025-06-30 08:38:23.914       1975.047      0.869125      2.330875
# 31443  2025-06-30 08:38:24.835       1975.969      0.868500      2.330625
#
#        PT-M01_2_3_V  reference_M_Pa
# 0          0.856500             0.0
# 141        0.858625             0.0
# 282        0.856875             0.0
# 423        0.860750             0.0
# 564        0.859625             0.0
# ...             ...             ...
# 30879      0.845625             0.0
# 31020      0.846750             0.0
# 31161      0.846375             0.0
# 31302      0.846750             0.0
# 31443      0.846625             0.0
#
# [224 rows x 6 columns]

# %%
# Вычисление производной давления по времени
selected_data['reference_M_Pa_diff'] = selected_data['reference_M_Pa'].diff() / selected_data['Relative_Time'].diff()
selected_data['PT-L01_2_1_V_diff'] = selected_data['PT-L01_2_1_V'].diff() / selected_data['Relative_Time'].diff()
selected_data['PT-M02_2_2_V_diff'] = selected_data['PT-M02_2_2_V'].diff() / selected_data['Relative_Time'].diff()
selected_data['PT-M01_2_3_V_diff'] = selected_data['PT-M01_2_3_V'].diff() / selected_data['Relative_Time'].diff()
# Out:
# /tmp/ipykernel_346296/3636275626.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['reference_M_Pa_diff'] = selected_data['reference_M_Pa'].diff() / selected_data['Relative_Time'].diff()
# /tmp/ipykernel_346296/3636275626.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['PT-L01_2_1_V_diff'] = selected_data['PT-L01_2_1_V'].diff() / selected_data['Relative_Time'].diff()
# /tmp/ipykernel_346296/3636275626.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['PT-M02_2_2_V_diff'] = selected_data['PT-M02_2_2_V'].diff() / selected_data['Relative_Time'].diff()
# /tmp/ipykernel_346296/3636275626.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['PT-M01_2_3_V_diff'] = selected_data['PT-M01_2_3_V'].diff() / selected_data['Relative_Time'].diff()

# %%
# Установка порога для определения установившегося режима
stabilization_threshold = 0.01  # Задайте порог, например, 0.001 МПа/с

# %%
# Фильтрация данных: выбираем строки, где производная давления близка к нулю
stable_data = selected_data[
    (selected_data['reference_M_Pa_diff'].abs() < stabilization_threshold)&
    (selected_data['PT-L01_2_1_V_diff'].abs() < stabilization_threshold)&
    (selected_data['PT-M02_2_2_V_diff'].abs() < stabilization_threshold)&
    (selected_data['PT-M01_2_3_V_diff'].abs() < stabilization_threshold)
    
]

# %%
stable_data.to_excel('./results/stable_data.xlsx')

# %%
# Построение графиков
plt.figure(figsize=(12, 8))
sns.scatterplot(data=stable_data, x='reference_M_Pa', y='PT-L01_2_1_V', label='PT-L01')
sns.scatterplot(data=stable_data, x='reference_M_Pa', y='PT-M02_2_2_V', label='PT-M02')
sns.scatterplot(data=stable_data, x='reference_M_Pa', y='PT-M01_2_3_V', label='PT-M01')
plt.xlabel('Давление на эталонном датчике, МПа')
plt.ylabel('Напряжение, В')
plt.title('Напряжение vs Давление на эталонном датчике (в установившемся режиме)')
plt.legend()
plt.savefig(f'./results/fig/exp_data_stable_data.png')
plt.show()

# %%
# Удалим данные более 6 МПа
stable_data_filtered = stable_data[stable_data['reference_M_Pa']<6]

# %%
# Построение графиков
plt.figure(figsize=(12, 8))
sns.scatterplot(data=stable_data_filtered, x='reference_M_Pa', y='PT-L01_2_1_V', label='PT-L01')
sns.scatterplot(data=stable_data_filtered, x='reference_M_Pa', y='PT-M02_2_2_V', label='PT-M02')
sns.scatterplot(data=stable_data_filtered, x='reference_M_Pa', y='PT-M01_2_3_V', label='PT-M01')
plt.xlabel('Давление на эталонном датчике, МПа')
plt.ylabel('Напряжение, В')
plt.title('Напряжение vs Давление на эталонном датчике (в установившемся режиме, до 6 МПА)')
plt.legend()
plt.savefig(f'./results/fig/exp_data_stable_data_limit.png')
plt.show()

# %%
def plot_regression_with_error(df, sensor_voltage, sensor_name):
    # Подготовка данных
    x = df[sensor_voltage].values.reshape(-1, 1)
    y = df['reference_M_Pa'].values

    # Создание и обучение модели линейной регрессии
    model = LinearRegression()
    model.fit(x, y)

    # Получение коэффициентов регрессии
    coef = model.coef_[0]
    intercept = model.intercept_

    # Предсказанные значения
    y_pred = model.predict(x)

    # Вычисление коэффициента детерминации R^2 и средней квадратичной ошибки
    r2 = r2_score(y, y_pred)
    mse = mean_squared_error(y, y_pred)

    # Вычисление средней относительной ошибки
    relative_errors = np.abs((y - y_pred) / y) * 100
    mean_relative_error = np.mean(relative_errors)

    # Построение графика
    plt.figure(figsize=(10, 6))
    plt.scatter(x, y, color='blue', label='Данные измерений')
    plt.plot(x, y_pred, color='red', label=f'Линия регрессии: y = {coef:.4f}x + {intercept:.4f}')
    plt.xlabel('Напряжение, В')
    plt.ylabel('Давление на эталонном датчике, МПа')
    plt.title(f'Линия регрессии. {sensor_name}\n$R^2 = {r2:.4f}$, MSE = {mse:.4f}, MRE = {mean_relative_error:.2f}%')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'./results/fig/regression_{sensor_name}.png')
    plt.show()
    print(f'{sensor_name} y = {coef}x + {intercept}')

    # Построение графика остатков
    residuals = y - y_pred
    plt.figure(figsize=(10, 4))
    plt.scatter(x, residuals, color='purple')
    plt.axhline(y=0, color='black', linestyle='--')
    plt.xlabel('Напряжение, В')
    plt.ylabel('Остатки, МПа')
    plt.title(f'График остатков. {sensor_name}')
    plt.grid(True)
    plt.savefig(f'./results/fig/residuals_{sensor_name}.png')
    plt.show()

# %%
df = stable_data_filtered[stable_data_filtered['reference_M_Pa']<4]

# %%
# Построение графиков для каждого датчика
plot_regression_with_error(df, 'PT-L01_2_1_V', 'PT-L01')
# Out:
# /tmp/ipykernel_346296/688682251.py:22: RuntimeWarning: divide by zero encountered in divide
#   relative_errors = np.abs((y - y_pred) / y) * 100
# PT-L01 y = 1.7330067905897815x + -1.5167404507291025

# %%
df = stable_data_filtered[stable_data_filtered['reference_M_Pa']<3.5]
plot_regression_with_error(df,'PT-M02_2_2_V', 'PT-M02')
# Out:
# /tmp/ipykernel_346296/688682251.py:22: RuntimeWarning: divide by zero encountered in divide
#   relative_errors = np.abs((y - y_pred) / y) * 100
# PT-M02 y = 1.756920543265745x + -4.104861493460779

# %%
plot_regression_with_error(stable_data_filtered,'PT-M01_2_3_V', 'PT-M01')
# Out:
# /tmp/ipykernel_346296/688682251.py:22: RuntimeWarning: divide by zero encountered in divide
#   relative_errors = np.abs((y - y_pred) / y) * 100
# PT-M01 y = 7.282911600941339x + -6.212822934064151

# %% [markdown]
# Коэффициенты детерминации 0.9996, 0.9999 и 1, указывают на то, что модель линейной регрессии очень хорошо объясняет вариацию данных. Это означает, что существует сильная линейная зависимость между напряжением на датчиках и эталонным давлением в МПа.
